# %%
# This helps debug an issue where FITS frames taken in spring/summer 2021
# case the GPI Data Pipeline to fail, apparently because not all the 
# expected FITS header keywords are present

# Created 2021 June 24 by E.S.

# %%
from astropy.io import fits
import pandas as pd

# %%
# read in text file of keywords pipeline expects

keys_df = pd.read_csv("./data/keywordconfig.txt", delim_whitespace=True, skiprows=2, names=["key","loc"])

# %%
keys_df
# Out:
#           key        loc
# 0      SIMPLE       Both
# 1      BITPIX       Both
# 2       NAXIS  Extension
# 3      NAXIS1  Extension
# 4      NAXIS2  Extension
# ..        ...        ...
# 273  DATAFILE        PHU
# 274  DATAPATH        PHU
# 275   EXPTIME  Extension
# 276    DRPVER        PHU
# 277  DRPNFILE        PHU
#
# [278 rows x 2 columns]

# %%
# read in example FITS file

hdul_old = fits.open("./data/S20191223S0005.fits") # older file
hdul_new = fits.open("./data/S20210624E0014.fits") # recent file

# %%
hdul_old.info()
# Out:
# Filename: ./data/S20191223S0005.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     197   ()
#   1  SCI           1 ImageHDU        74   (2048, 2048)   float32
#   2  DQ            3 ImageHDU        63   (2048, 2048)   uint8

# %%
hdul_new.info()
# Out:
# Filename: ./data/S20210624E0014.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     130   ()
#   1  SCI           1 ImageHDU        74   (2048, 2048)   float32
#   2  DQ            3 ImageHDU        63   (2048, 2048)   uint8

# %%
# loop through each key the pipeline expects (as stated in text file), and see if it exists in the right extension

for key_num in range(0,len(keys_df)):
    
    # what/where should key be?
    key_name = keys_df["key"].iloc[key_num]
    key_loc = keys_df["loc"].iloc[key_num]
    
    print("This key: " + key_name)
    
    if (key_loc == "PHU"):
        
        print("Looking in PHU:")
        print(key_name in list(hdul[0].header.keys()))
        
    elif (key_loc == "Extension"):
        
        print("Looking in Extension:")
        print(key_name in list(hdul[1].header.keys()))
        
    elif (key_loc == "Both"):
        
        print("Looking in Both:")
        print(key_name in list(hdul[0].header.keys()))
        print(key_name in list(hdul[1].header.keys()))
        
    else:
        
        print("No legit key!")
        
    print("------------")
# Out:
# This key: SIMPLE
# Looking in Both:
# True
# False
# ------------
# This key: BITPIX
# Looking in Both:
# True
# True
# ------------
# This key: NAXIS
# Looking in Extension:
# True
# ------------
# This key: NAXIS1
# Looking in Extension:
# True
# ------------
# This key: NAXIS2
# Looking in Extension:
# True
# ------------
# This key: NAXIS3
# Looking in Extension:
# False
# ------------
# This key: HISTORY
# Looking in Both:
# False
# False
# ------------
# This key: CTYPE1
# Looking in Extension:
# True
# ------------
# This key: CD1_1
# Looking in Extension:
# True
# ------------
# This key: CD1_2
# Looking in Extension:
# True
# ------------
# This key: CD2_1
# Looking in Extension:
# True
# ------------
# This key: CD2_2
# Looking in Extension:
# True
# ------------
# This key: CD3_3
# Looking in Extension:
# False
# ------------
# This key: CDELT1
# Looking in Extension:
# True
# ------------
# This key: CDELT2
# Looking in Extension:
# True
# ------------
# This key: CDELT3
# Looking in Extension:
# False
# ------------
# This key: CRPIX1
# Looking in Extension:
# True
# ------------
# This key: CRPIX2
# Looking in Extension:
# True
# ------------
# This key: CRPIX3
# Looking in Extension:
# False
# ------------
# This key: CRVAL1
# Looking in Extension:
# True
# ------------
# This key: CRVAL2
# Looking in Extension:
# True
# ------------
# This key: CRVAL3
# Looking in Extension:
# False
# ------------
# This key: CTYPE1
# Looking in Extension:
# True
# ------------
# This key: CTYPE2
# Looking in Extension:
# True
# ------------
# This key: CTYPE3
# Looking in Extension:
# False
# ------------
# This key: CUNIT3
# Looking in Extension:
# False
# ------------
# This key: CUNIT
# Looking in Extension:
# False
# ------------
# This key: CUNIT1
# Looking in Extension:
# True
# ------------
# This key: CUNIT2
# Looking in Extension:
# True
# ------------
# This key: CUNIT3
# Looking in Extension:
# False
# ------------
# This key: AOFILTER
# Looking in PHU:
# True
# ------------
# This key: AOSPATIA
# Looking in PHU:
# True
# ------------
# This key: ARTINT
# Looking in PHU:
# True
# ------------
# This key: ADC
# Looking in PHU:
# True
# ------------
# This key: ADCANGLE
# Looking in PHU:
# True
# ------------
# This key: ADCCAR
# Looking in PHU:
# False
# ------------
# This key: ADCPOW
# Looking in PHU:
# True
# ------------
# This key: APODCAR
# Looking in PHU:
# False
# ------------
# This key: APODIZER
# Looking in PHU:
# True
# ------------
# This key: ARTSRC
# Looking in PHU:
# True
# ------------
# This key: CALREFSH
# Looking in PHU:
# True
# ------------
# This key: CALSCISH
# Looking in PHU:
# True
# ------------
# This key: CALENSH
# Looking in PHU:
# True
# ------------
# This key: CALEXSH
# Looking in PHU:
# True
# ------------
# This key: CALFILT
# Looking in PHU:
# False
# ------------
# This key: CFLTCAR
# Looking in PHU:
# False
# ------------
# This key: CORNMASK
# Looking in PHU:
# False
# ------------
# This key: DISPCAR
# Looking in PHU:
# False
# ------------
# This key: DISPERSR
# Looking in PHU:
# True
# ------------
# This key: FILTER1
# Looking in PHU:
# False
# ------------
# This key: IFSFILT
# Looking in PHU:
# True
# ------------
# This key: GPIHEALT
# Looking in PHU:
# True
# ------------
# This key: IFSSHUT
# Looking in PHU:
# False
# ------------
# This key: LYOTCAR
# Looking in PHU:
# False
# ------------
# This key: LYOTMASK
# Looking in PHU:
# True
# ------------
# This key: OCCCAR
# Looking in PHU:
# False
# ------------
# This key: OCCULTER
# Looking in PHU:
# True
# ------------
# This key: OMSSENT
# Looking in PHU:
# True
# ------------
# This key: OMSEXIT
# Looking in PHU:
# False
# ------------
# This key: OBSMODE
# Looking in PHU:
# True
# ------------
# This key: PUPVIEWR
# Looking in PHU:
# True
# ------------
# This key: WPANGCAR
# Looking in PHU:
# False
# ------------
# This key: WPANGLE
# Looking in PHU:
# True
# ------------
# This key: WPSTATE
# Looking in PHU:
# True
# ------------
# This key: POLARIZ
# Looking in PHU:
# False
# ------------
# This key: SIMLEVEL
# Looking in PHU:
# True
# ------------
# This key: ARRAYID
# Looking in PHU:
# True
# ------------
# This key: CCDNAME
# Looking in PHU:
# True
# ------------
# This key: ABORTED
# Looking in Extension:
# True
# ------------
# This key: ABORTLVL
# Looking in Extension:
# False
# ------------
# This key: BUNIT
# Looking in Extension:
# True
# ------------
# This key: CELLDRAN
# Looking in Extension:
# True
# ------------
# This key: CLKSPEED
# Looking in Extension:
# True
# ------------
# This key: COADDS
# Looking in Extension:
# True
# ------------
# This key: COADDS0
# Looking in Extension:
# True
# ------------
# This key: CCDSIZE
# Looking in PHU:
# True
# ------------
# This key: DATASEC
# Looking in Extension:
# True
# ------------
# This key: DETENDX
# Looking in Extension:
# True
# ------------
# This key: DETENDY
# Looking in Extension:
# True
# ------------
# This key: DETGAIN
# Looking in Extension:
# True
# ------------
# This key: DETSTRTX
# Looking in Extension:
# True
# ------------
# This key: DETSTRTY
# Looking in Extension:
# True
# ------------
# This key: DRAIN
# Looking in Extension:
# True
# ------------
# This key: DSUB
# Looking in Extension:
# True
# ------------
# This key: DTGAINDB
# Looking in Extension:
# True
# ------------
# This key: DTGAINNM
# Looking in Extension:
# True
# ------------
# This key: GROUPS
# Looking in Extension:
# False
# ------------
# This key: NGROUP
# Looking in Extension:
# True
# ------------
# This key: NGROUPS
# Looking in Extension:
# False
# ------------
# This key: GROUPS0
# Looking in Extension:
# True
# ------------
# This key: HRPSTYPE
# Looking in Extension:
# True
# ------------
# This key: HXRGCFG1
# Looking in Extension:
# True
# ------------
# This key: HXRGCFG2
# Looking in Extension:
# True
# ------------
# This key: HXRGVERS
# Looking in Extension:
# True
# ------------
# This key: IGNORDRD
# Looking in Extension:
# True
# ------------
# This key: ITIME
# Looking in Extension:
# True
# ------------
# This key: ITIME0
# Looking in Extension:
# True
# ------------
# This key: LONGSTRN
# Looking in Extension:
# True
# ------------
# This key: RDITIME
# Looking in Extension:
# True
# ------------
# This key: READS
# Looking in Extension:
# True
# ------------
# This key: READS0
# Looking in Extension:
# True
# ------------
# This key: RMPDROP
# Looking in Extension:
# True
# ------------
# This key: RMPGROUP
# Looking in Extension:
# True
# ------------
# This key: RMPREADS
# Looking in Extension:
# True
# ------------
# This key: RMPRESET
# Looking in Extension:
# True
# ------------
# This key: SAMPMODE
# Looking in Extension:
# True
# ------------
# This key: SATURATE
# Looking in Extension:
# True
# ------------
# This key: SYSGAIN
# Looking in Extension:
# True
# ------------
# This key: VBIASGAT
# Looking in Extension:
# True
# ------------
# This key: VBIASPWR
# Looking in Extension:
# True
# ------------
# This key: VDD
# Looking in Extension:
# True
# ------------
# This key: VDDA
# Looking in Extension:
# True
# ------------
# This key: VPRAMRF1
# Looking in Extension:
# True
# ------------
# This key: VPREMDRF
# Looking in Extension:
# True
# ------------
# This key: VREFMAIN
# Looking in Extension:
# True
# ------------
# This key: VRESET
# Looking in Extension:
# True
# ------------
# This key: VRPSTYPE
# Looking in Extension:
# True
# ------------
# This key: CWSTEMP
# Looking in PHU:
# True
# ------------
# This key: DETTEMP
# Looking in PHU:
# True
# ------------
# This key: DETHTEMP
# Looking in PHU:
# True
# ------------
# This key: DEWPRES
# Looking in PHU:
# False
# ------------
# This key: UTSTART
# Looking in PHU:
# True
# ------------
# This key: DATE-OBS
# Looking in PHU:
# True
# ------------
# This key: MJD-OBS
# Looking in PHU:
# True
# ------------
# This key: TIME-END
# Looking in PHU:
# False
# ------------
# This key: TIME-OBS
# Looking in PHU:
# False
# ------------
# This key: UTEND
# Looking in PHU:
# True
# ------------
# This key: READTIME
# Looking in Extension:
# True
# ------------
# This key: AVPARANG
# Looking in Extension:
# False
# ------------
# This key: EXPSTART
# Looking in Extension:
# False
# ------------
# This key: EXPEND
# Looking in Extension:
# False
# ------------
# This key: MJD-AVG
# Looking in PHU:
# False
# ------------
# This key: AIRMASS
# Looking in PHU:
# True
# ------------
# This key: AMEND
# Looking in PHU:
# True
# ------------
# This key: AMSTART
# Looking in PHU:
# True
# ------------
# This key: AOFOLD
# Looking in PHU:
# True
# ------------
# This key: AZIMUTH
# Looking in PHU:
# True
# ------------
# This key: CRFOLLOW
# Looking in PHU:
# True
# ------------
# This key: CRPA
# Looking in PHU:
# True
# ------------
# This key: DATALAB
# Looking in PHU:
# True
# ------------
# This key: DATAFILE
# No legit key!
# ------------
# This key: DATE
# Looking in PHU:
# True
# ------------
# This key: DEC
# Looking in PHU:
# True
# ------------
# This key: DECOFFSE
# Looking in PHU:
# True
# ------------
# This key: DECTRACK
# Looking in PHU:
# True
# ------------
# This key: DECTRGOF
# Looking in PHU:
# True
# ------------
# This key: DEWPOIN2
# Looking in PHU:
# True
# ------------
# This key: DEWPOINT
# Looking in PHU:
# True
# ------------
# This key: ELEVATIO
# Looking in PHU:
# True
# ------------
# This key: EPOCH
# Looking in PHU:
# True
# ------------
# This key: EQUINOX
# Looking in PHU:
# True
# ------------
# This key: GCALDIFF
# Looking in PHU:
# True
# ------------
# This key: GCALFILT
# Looking in PHU:
# True
# ------------
# This key: GCALLAMP
# Looking in PHU:
# True
# ------------
# This key: GCALSHUT
# Looking in PHU:
# True
# ------------
# This key: GEMPRGID
# Looking in PHU:
# True
# ------------
# This key: HA
# Looking in PHU:
# True
# ------------
# This key: HUMIDITY
# Looking in PHU:
# True
# ------------
# This key: IAA
# Looking in PHU:
# True
# ------------
# This key: INPORT
# Looking in PHU:
# True
# ------------
# This key: INSTRUME
# Looking in PHU:
# True
# ------------
# This key: INSTRSUB
# Looking in Extension:
# True
# ------------
# This key: LT
# Looking in PHU:
# True
# ------------
# This key: M2BAFFLE
# Looking in PHU:
# True
# ------------
# This key: M2CENBAF
# Looking in PHU:
# True
# ------------
# This key: OBJECT
# Looking in PHU:
# True
# ------------
# This key: OBSCLASS
# Looking in PHU:
# True
# ------------
# This key: OBSERVAT
# Looking in PHU:
# True
# ------------
# This key: OBSERVER
# Looking in PHU:
# True
# ------------
# This key: OBSID
# Looking in PHU:
# True
# ------------
# This key: OBSTYPE
# Looking in PHU:
# True
# ------------
# This key: PA
# Looking in PHU:
# True
# ------------
# This key: PAR_ANG
# Looking in PHU:
# True
# ------------
# This key: PARALLAX
# Looking in PHU:
# True
# ------------
# This key: PMDEC
# Looking in PHU:
# True
# ------------
# This key: PMRA
# Looking in PHU:
# True
# ------------
# This key: POFFSET
# Looking in PHU:
# True
# ------------
# This key: PRESSUR2
# Looking in PHU:
# True
# ------------
# This key: PRESSURE
# Looking in PHU:
# True
# ------------
# This key: QOFFSET
# Looking in PHU:
# True
# ------------
# This key: RA
# Looking in PHU:
# True
# ------------
# This key: RADESYS
# Looking in PHU:
# False
# ------------
# This key: RADVEL
# Looking in PHU:
# True
# ------------
# This key: RAOFFSET
# Looking in PHU:
# True
# ------------
# This key: RATRACK
# Looking in PHU:
# True
# ------------
# This key: RATRGOFF
# Looking in PHU:
# True
# ------------
# This key: RAWBG
# Looking in PHU:
# True
# ------------
# This key: RAWCC
# Looking in PHU:
# True
# ------------
# This key: RAWGEMQA
# Looking in PHU:
# True
# ------------
# This key: RAWIQ
# Looking in PHU:
# True
# ------------
# This key: RAWPIREQ
# Looking in PHU:
# True
# ------------
# This key: RAWWV
# Looking in PHU:
# True
# ------------
# This key: SFLINEAR
# Looking in PHU:
# True
# ------------
# This key: SFRT2
# Looking in PHU:
# True
# ------------
# This key: SFTILT
# Looking in PHU:
# True
# ------------
# This key: SSA
# Looking in PHU:
# True
# ------------
# This key: ST
# Looking in PHU:
# True
# ------------
# This key: TAMBIEN2
# Looking in PHU:
# True
# ------------
# This key: TAMBIENT
# Looking in PHU:
# True
# ------------
# This key: TELESCOP
# Looking in PHU:
# True
# ------------
# This key: TRKEPOCH
# Looking in PHU:
# True
# ------------
# This key: TRKEQUIN
# Looking in PHU:
# True
# ------------
# This key: TRKFRAME
# Looking in PHU:
# True
# ------------
# This key: UT
# Looking in PHU:
# True
# ------------
# This key: WAVELENG
# Looking in PHU:
# True
# ------------
# This key: WINDDIRE
# Looking in PHU:
# True
# ------------
# This key: WINDSPE2
# Looking in PHU:
# True
# ------------
# This key: WINDSPEE
# Looking in PHU:
# True
# ------------
# This key: XOFFSET
# Looking in PHU:
# True
# ------------
# This key: YOFFSET
# Looking in PHU:
# True
# ------------
# This key: GEADIMM
# Looking in PHU:
# False
# ------------
# This key: GEAMASS
# Looking in PHU:
# False
# ------------
# This key: GEAT0
# Looking in PHU:
# False
# ------------
# This key: SPECTYPE
# Looking in PHU:
# False
# ------------
# This key: HMAG
# Looking in PHU:
# True
# ------------
# This key: STMAG
# Looking in PHU:
# True
# ------------
# This key: SECDIAM
# Looking in PHU:
# False
# ------------
# This key: TELDIAM
# Looking in PHU:
# False
# ------------
# This key: EXTEND
# Looking in PHU:
# True
# ------------
# This key: NEXTEND
# Looking in PHU:
# True
# ------------
# This key: INHERIT
# Looking in PHU:
# False
# ------------
# This key: EXTVER
# Looking in Extension:
# True
# ------------
# This key: EXTNAME
# Looking in Extension:
# True
# ------------
# This key: AOWFE
# Looking in PHU:
# True
# ------------
# This key: SKYTRANS
# Looking in PHU:
# False
# ------------
# This key: CALON
# Looking in PHU:
# True
# ------------
# This key: AOON
# Looking in PHU:
# True
# ------------
# This key: OPTON
# Looking in PHU:
# True
# ------------
# This key: AOZERN
# Looking in PHU:
# False
# ------------
# This key: AOFRAMES
# Looking in PHU:
# True
# ------------
# This key: M2OFFLOA
# Looking in PHU:
# True
# ------------
# This key: RMSTIP
# Looking in PHU:
# False
# ------------
# This key: RMSTILT
# Looking in PHU:
# False
# ------------
# This key: RMSFOCU
# Looking in PHU:
# False
# ------------
# This key: RMSERR
# Looking in PHU:
# True
# ------------
# This key: AVGRNOT
# Looking in PHU:
# True
# ------------
# This key: FLUX
# Looking in PHU:
# True
# ------------
# This key: AVEINT
# Looking in PHU:
# False
# ------------
# This key: STREHL
# Looking in PHU:
# False
# ------------
# This key: PipelineVER
# Looking in PHU:
# False
# ------------
# This key: FILETYPE
# Looking in PHU:
# False
# ------------
# This key: FSCALE[i]
# Looking in Extension:
# False
# ------------
# This key: FSCALE0
# Looking in Extension:
# False
# ------------
# This key: FSCALE1
# Looking in Extension:
# False
# ------------
# This key: FSCALE2
# Looking in Extension:
# False
# ------------
# This key: FSCALE3
# Looking in Extension:
# False
# ------------
# This key: ISCALIB
# Looking in Both:
# False
# False
# ------------
# This key: PC1_1
# Looking in Extension:
# False
# ------------
# This key: PC1_2
# Looking in Extension:
# False
# ------------
# This key: PC2_1
# Looking in Extension:
# False
# ------------
# This key: PC2_2
# Looking in Extension:
# False
# ------------
# This key: PC3_3
# Looking in Extension:
# False
# ------------
# This key: PSFCENTX
# Looking in Extension:
# False
# ------------
# This key: PSFCENTY
# Looking in Extension:
# False
# ------------
# This key: SPECCENX
# Looking in Extension:
# False
# ------------
# This key: SPECCENY
# Looking in Extension:
# False
# ------------
# This key: SPOT1x
# Looking in Extension:
# False
# ------------
# This key: SPOT1y
# Looking in Extension:
# False
# ------------
# This key: SPOT2x
# Looking in Extension:
# False
# ------------
# This key: SPOT2y
# Looking in Extension:
# False
# ------------
# This key: SPOT3x
# Looking in Extension:
# False
# ------------
# This key: SPOT3y
# Looking in Extension:
# False
# ------------
# This key: SPOT4x
# Looking in Extension:
# False
# ------------
# This key: SPOT4y
# Looking in Extension:
# False
# ------------
# This key: SPOTWAVE
# Looking in Extension:
# False
# ------------
# This key: WCSAXES
# Looking in Extension:
# False
# ------------
# This key: DARKFILE
# Looking in PHU:
# False
# ------------
# This key: FLATFILE
# Looking in PHU:
# False
# ------------
# This key: BGFILE
# Looking in PHU:
# False
# ------------
# This key: REFCENT
# Looking in PHU:
# False
# ------------
# This key: LOCENTR
# Looking in PHU:
# False
# ------------
# This key: HOREFWV
# Looking in PHU:
# False
# ------------
# This key: ASTROMTC
# Looking in PHU:
# True
# ------------
# This key: DATAFILE
# Looking in PHU:
# False
# ------------
# This key: DATAPATH
# Looking in PHU:
# False
# ------------
# This key: EXPTIME
# Looking in Extension:
# False
# ------------
# This key: DRPVER
# Looking in PHU:
# False
# ------------
# This key: DRPNFILE
# Looking in PHU:
# False
# ------------

# %%
# loop through each key in the old FITS file, and see if they exist in new FITS file

list_old_0 = list(hdul_old[0].header.keys())
list_new_0 = list(hdul_new[0].header.keys())

# loop over keys in extension 0
counter = 0
for key_num in range(0,len(list_old_0)):
    
    # what key?
    key_name = list_old_0[key_num]
    if not (key_name in list_new_0):
        print("This key: " + key_name)
        print(key_name)
        counter += 1
        print("------------")
        
print(counter)
# Out:
# This key: AIRMASS
# AIRMASS
# ------------
# This key: AMEND
# AMEND
# ------------
# This key: AMSTART
# AMSTART
# ------------
# This key: AOFOLD
# AOFOLD
# ------------
# This key: ASTROMTC
# ASTROMTC
# ------------
# This key: CRFOLLOW
# CRFOLLOW
# ------------
# This key: CRPA
# CRPA
# ------------
# This key: DATALAB
# DATALAB
# ------------
# This key: DATE
# DATE
# ------------
# This key: DECOFFSE
# DECOFFSE
# ------------
# This key: DECTRACK
# DECTRACK
# ------------
# This key: DECTRGOF
# DECTRGOF
# ------------
# This key: DEWPOIN2
# DEWPOIN2
# ------------
# This key: DEWPOINT
# DEWPOINT
# ------------
# This key: EPOCH
# EPOCH
# ------------
# This key: EQUINOX
# EQUINOX
# ------------
# This key: GCALDIFF
# GCALDIFF
# ------------
# This key: GCALFILT
# GCALFILT
# ------------
# This key: GCALLAMP
# GCALLAMP
# ------------
# This key: GCALSHUT
# GCALSHUT
# ------------
# This key: GEMPRGID
# GEMPRGID
# ------------
# This key: HA
# HA
# ------------
# This key: IAA
# IAA
# ------------
# This key: INPORT
# INPORT
# ------------
# This key: LT
# LT
# ------------
# This key: M2BAFFLE
# M2BAFFLE
# ------------
# This key: M2CENBAF
# M2CENBAF
# ------------
# This key: OBSCLASS
# OBSCLASS
# ------------
# This key: OBSERVAT
# OBSERVAT
# ------------
# This key: OBSERVER
# OBSERVER
# ------------
# This key: OBSID
# OBSID
# ------------
# This key: OBSTYPE
# OBSTYPE
# ------------
# This key: PA
# PA
# ------------
# This key: PARALLAX
# PARALLAX
# ------------
# This key: PMDEC
# PMDEC
# ------------
# This key: PMRA
# PMRA
# ------------
# This key: POFFSET
# POFFSET
# ------------
# This key: PRESSUR2
# PRESSUR2
# ------------
# This key: PROP_MD
# PROP_MD
# ------------
# This key: QOFFSET
# QOFFSET
# ------------
# This key: RADVEL
# RADVEL
# ------------
# This key: RAOFFSET
# RAOFFSET
# ------------
# This key: RATRACK
# RATRACK
# ------------
# This key: RATRGOFF
# RATRGOFF
# ------------
# This key: RAWBG
# RAWBG
# ------------
# This key: RAWCC
# RAWCC
# ------------
# This key: RAWGEMQA
# RAWGEMQA
# ------------
# This key: RAWIQ
# RAWIQ
# ------------
# This key: RAWPIREQ
# RAWPIREQ
# ------------
# This key: RAWWV
# RAWWV
# ------------
# This key: RELEASE
# RELEASE
# ------------
# This key: SCIBAND
# SCIBAND
# ------------
# This key: SFLINEAR
# SFLINEAR
# ------------
# This key: SFRT2
# SFRT2
# ------------
# This key: SFTILT
# SFTILT
# ------------
# This key: SSA
# SSA
# ------------
# This key: ST
# ST
# ------------
# This key: TAMBIEN2
# TAMBIEN2
# ------------
# This key: TRKEPOCH
# TRKEPOCH
# ------------
# This key: TRKEQUIN
# TRKEQUIN
# ------------
# This key: TRKFRAME
# TRKFRAME
# ------------
# This key: UT
# UT
# ------------
# This key: WAVELENG
# WAVELENG
# ------------
# This key: WINDDIRE
# WINDDIRE
# ------------
# This key: WINDSPE2
# WINDSPE2
# ------------
# This key: XOFFSET
# XOFFSET
# ------------
# This key: YOFFSET
# YOFFSET
# ------------
# 67

# %%
hdul[0].header.keys
# Out:
# <bound method Header.keys of SIMPLE  =                    T / C# FITS: 6/24/2021 12:58:22 PM
# BITPIX  =                    8
# NAXIS   =                    0
# EXTEND  =                    T / Extensions are permitted
# LONGSTRN= 'OGIP 1.0'           /  The OGIP Long String Convention may be used.
# AOFILTER= 'AOFILT_700NM_G1222' / AO WFS filter selected
# AOFLHLTH= 'GOOD    '           / AO WFS filter health state
# AOSPATIA=                 2.80 / Current size of AO spatial filter
# ARTINT  =                 60.0 / Broadband source intensity
# ADC     = 'OUT     '           / ADC (DEPLOYED/EXTRACTED)
# ADCANGLE=                 0.00 / ADC achieved orientation (deg)
# ADCHLTH = 'GOOD    '           / ADC (in/out) Health
# ADCPOW  =                 1.75 / ADC achieved power (deg)
# AOFOLDTP=                 0.02 / AO Pick-Off Mirror Tip Position
# AOFOLDTT=                -0.05 / AO Pick-Off Mirror Tilt Position
# APODHLTH= 'GOOD    '           / Pupil Plane Mask (Apodizer) health
# APODIZER= 'APOD_CLEAR_G6201'   / Pupil Plane Mask (Apodizer) selected
# ARTSRC  = 'GPI_DEPLOY_IN'      / Artificial source selected
# ARTIR   = 'GPI_SRC_OFF'        / IR Source state
# ARTVIS  = 'GPI_SRC_OFF'        / VIS source state
# SCSTATE = 'GPI_SRC_ON'         / SC source state
# SCPOW   =               100.00 / SC Amplifier power
# CALREFSH= 'CLOSED  '           / State of CAL reference arm shutter
# CALSCISH= 'CLOSED  '           / State of CAL science arm shutter
# CALENSH = 'OPEN    '           / State of CAL Entrance shutter
# CALEXSH = 'OPEN    '           / State of CAL Exit shutter
# CALSPHER= 'GPI_SRC_OFF'        / CAL Sphere deployed
# CALSPHAT=                60.00 / CAL Sphere  Attenuation in db
# DISPHLTH= 'GOOD    '           / DISPERSER Health state
# DISPERSR= 'DISP_PRISM_G6262'   / Wollaston/Prism/Open
# IFSFILT = 'IFSFILT_H_G1213'    / Filter name
# IFSFLHLT= 'BAD     '           / Filter 1 Health state
# GPIHEALT= 'BAD     '           / GPI health
# LYOTHLTH= 'GOOD    '           / Lyot mask Health state
# LYOTMASK= 'LYOT_OPEN_G6231'    / Lyot mask selected
# OCCHLTH = 'GOOD    '           / Occulter position health state
# OCCULTER= 'FPM_SCIENCE_G6227'  / Occulter position
# OMSSENT = 'CLOSED  '           / State of OMSS Entrance shutter
# OBSMODE = 'H_direct'           / Currently selected observation Mode
# PUPVIEWR= '0       '           / Is the pupil viewing mirror inserted
# WPANGHLT= 'GOOD    '           / Half-wave plate position health
# WPANGLE =                67.50 / Half-wave plate position
# WPSTATE = 'OUT     '           / Half-wave plate state
# SIMLEVEL= 'OUT     '           / Simulate state
# TTRKFOLD= 'FALSE   '           / TLC Track assembly Fold tracking status(T/F)
# TTRKAOWF= 'TRUE    '           / TLC Track assembly AOWFS tracking status(T/F)
# TTRKCALI= 'FALSE   '           / TLC Track assembly CALIFS tracking status(T/F)
# TAPPUPOF= 'FALSE   '           / TLC Track assembly apply pupil offsets(T/F)
# TAPLYOTO= 'TRUE    '           / TLC Track assembly apply Lyot offset(T/F)
# TAPPDARO= 'FALSE   '           / TLC Track assembly apply DAR residuals(T/F)
# TAOWFSOL= 'TRUE    '           / TLC Track assembly apply AOWFS Open Loop model(
# TAFOLDOL= 'FALSE   '           / TLC Track assembly apply FOLD open model(T/F)
# TACALIOL= 'TRUE    '           / TLC Track assembly apply CALIFS Open Loop model
# TAAOSPOL= 'TRUE    '           / TLC Track assembly apply AOSPAT Temp Correction
# TAOSPTMX=                0.692 / TLC AO assembly AOSPAT X Motor position
# TAOSPTMY=                2.134 / TLC AO assembly AOSPAT Y Motor position
# TSRCPOSX=                0.097 / TLC SRC assembly Source X Motor position
# TSRCPOSY=               -1.450 / TLC SRC assembly Source Y Motor position
# CALMTILT=               27.478 / TLC CAL BIAS TILT value
# CALMTIP =              -31.213 / TLC CAL BIAS TIP value
# ARRAYID = 'HAWAII-II RG S/N 201' / Array serial number
# CCDNAME = 'HAWAII2-RG'         / Array name
# WFSDTEMP=               258.45 / AOWFS detector temperature (K)
# GLITEMP =                10.13 / Glycol Input Temp (C)
# GLOTEMP =                13.25 / Glycol Output Temp (C)
# AEXITEMP=                26.88 / Air Heat Ex Input Temp (C)
# AEXOTEMP=                15.44 / Air Heat Ex Output Temp (C)
# OMSATEMP=                16.88 / Avg OMSS AORelay Temp (C)
# OMSMTEMP=                19.00 / Max OMSS AORelay Temp (C)
# IFSITEMP=                 9.44 / INSTRUMENT Cryo Glycol Input Temp (C)
# IFSOTEMP=                10.50 / INSTRUMENT Cryo Glycol Output Temp (C)
# EEHUMID =                 3.82 / Electronic Enclosure Humidity
# MEMHUMID=                 1.16 / MEMS Humidity %
# OMSHUMID=                 5.14 / Max OMSS Humidity %
# AMBHUMID=                11.58 / Mean Ambient Humidity%
# CWSTEMP =               480.00 / Cold work surface temperature (K)
# DETTEMP =                83.11 / Detector temperature (K)
# DETHTEMP=                83.18 / Detector housing temperature (K)
# DEWPRES1=             6.40E-03 / Dewar pressure (mTorr)
# DEWPRES2=             5.75E-03 / Dewar pressure (mTorr)
# SUPCTEMP=                29.00 / Super Continuum temp (C)
# MJD-OBS =   59389.666184629925 / MJD of start of observation
# AZIMUTH =            265.00029 / Telescope Azimuth at the start of exposure
# DEC     =           -24.201425 / Target Declination
# ELEVATIO=            44.999565 / Telescope Elevation at the start of exposure
# HUMIDITY=            21.799999 / The Relative Humidity (fraction, 0..101).
# INSTRUME= 'GPI     '           / Instrument used to acquire data
# OBJECT  = 'Domeflat'           / Object Name
# PAR_ANG =            109.38618 / Parallactic angle
# PRESSURE=             728.7533 / The atmospheric pressure (mm Hg).
# RA      =            30.978017 / Target Right Ascension
# TAMBIENT=                  5.0 / The ambient temp (C).
# TELESCOP= 'Gemini-South'       / Name of telescope (Gemini-North|Gemini-South)
# WINDSPEE=            8.6999998 / The wind speed (m/s).
# DIMTSTMP=                  999 / DIMM time stamp, minutes since last update. Val
# MASTSTMP=                  999 / MASS time stamp, minutes since last update. Val
# HMAG    =                  0.0 / H magnitude of the target
# STMAG   =                  4.0 / I magnitude of the target
# AOWFE   =                 0.00 / Average wavefront residual error during exposur
# CALON   = 'FALSE   '           / Is OIWFS currently reacting to data from the CA
# AOON    = 'FALSE   '           / Is the GPI servo loop running?
# OPTON   = 'YES     '           / Optimizing wavefront
# AOFRAMES=              1000.00 / AO camera frame rate
# M2OFFLOA= 'NO      '           / m2 offloading
# CALTIP  =               -31.21 / Measured LOWFS TIP (cal.calTarget.calTargetPand
# CALTILT =                27.48 / Measured LOWFS TILT (cal.calTarget.calTargetPan
# CALFOCU =              -117.53 / Measured LOWFS FOCUS (cal.calTarget.calTargetPa
# RMSERR  =                 0.00 / RMS Wavefront Error
# AVGRNOT =               115.19 / r0 average estimate
# FLUX    =                 9.39 / AO average Flux reported
# CALLOOP = 'FALSE   '           / CAL offloading loop status
# AOCLOOP = 'FALSE   '           / AOC offloading loop status
# WOFLOOP = 'FALSE   '           / Woofer offloading loop status
# AOTTLOOP= 'FALSE   '           / TIP/TILT offloading loop status
# AOMINSNR=                 0.00 / AO Minimum SNR setting
# CALBTIP =               -30.91 / CAL tip bias level
# CALBTILT=                27.64 / CAL tilt bias level
# CALFOCUS=                59.95 / CAL focus bias level
# M1OFLOAD= 'FALSE   '           / M1 offloading
# GMPVER  = '14.4.1  '           / Version number of GMP software
# GDSVER  = '14.4.1  '           / Version number of GDS software
# IFSVER  = '        '           / Version number of GPI IFS software
# AOVER   = '0.7     '           / Version number of GPI AO software
# CALVER  = '0.9.4   '           / Version number of GPI CAL software
# TLCVER  = '0.8     '           / Version number of GPI TLC software
# NEXTEND =                    2 / Number of extensions
# DATE-OBS= '2021-06-24'         /  UT start date of exposure
# UTSTART = '15:58:17.260'       /  UT start time of exposure
# UTEND   = '15:58:22.416'       /  UT end time of exposure (after last read)
# CCDSIZE = '2048x2048'          /  Array dimensions                              >

# %%
list(hdul[0].header.keys())
# Out:
# ['SIMPLE',
#  'BITPIX',
#  'NAXIS',
#  'EXTEND',
#  'LONGSTRN',
#  'AOFILTER',
#  'AOFLHLTH',
#  'AOSPATIA',
#  'ARTINT',
#  'ADC',
#  'ADCANGLE',
#  'ADCHLTH',
#  'ADCPOW',
#  'AOFOLDTP',
#  'AOFOLDTT',
#  'APODHLTH',
#  'APODIZER',
#  'ARTSRC',
#  'ARTIR',
#  'ARTVIS',
#  'SCSTATE',
#  'SCPOW',
#  'CALREFSH',
#  'CALSCISH',
#  'CALENSH',
#  'CALEXSH',
#  'CALSPHER',
#  'CALSPHAT',
#  'DISPHLTH',
#  'DISPERSR',
#  'IFSFILT',
#  'IFSFLHLT',
#  'GPIHEALT',
#  'LYOTHLTH',
#  'LYOTMASK',
#  'OCCHLTH',
#  'OCCULTER',
#  'OMSSENT',
#  'OBSMODE',
#  'PUPVIEWR',
#  'WPANGHLT',
#  'WPANGLE',
#  'WPSTATE',
#  'SIMLEVEL',
#  'TTRKFOLD',
#  'TTRKAOWF',
#  'TTRKCALI',
#  'TAPPUPOF',
#  'TAPLYOTO',
#  'TAPPDARO',
#  'TAOWFSOL',
#  'TAFOLDOL',
#  'TACALIOL',
#  'TAAOSPOL',
#  'TAOSPTMX',
#  'TAOSPTMY',
#  'TSRCPOSX',
#  'TSRCPOSY',
#  'CALMTILT',
#  'CALMTIP',
#  'ARRAYID',
#  'CCDNAME',
#  'WFSDTEMP',
#  'GLITEMP',
#  'GLOTEMP',
#  'AEXITEMP',
#  'AEXOTEMP',
#  'OMSATEMP',
#  'OMSMTEMP',
#  'IFSITEMP',
#  'IFSOTEMP',
#  'EEHUMID',
#  'MEMHUMID',
#  'OMSHUMID',
#  'AMBHUMID',
#  'CWSTEMP',
#  'DETTEMP',
#  'DETHTEMP',
#  'DEWPRES1',
#  'DEWPRES2',
#  'SUPCTEMP',
#  'MJD-OBS',
#  'AZIMUTH',
#  'DEC',
#  'ELEVATIO',
#  'HUMIDITY',
#  'INSTRUME',
#  'OBJECT',
#  'PAR_ANG',
#  'PRESSURE',
#  'RA',
#  'TAMBIENT',
#  'TELESCOP',
#  'WINDSPEE',
#  'DIMTSTMP',
#  'MASTSTMP',
#  'HMAG',
#  'STMAG',
#  'AOWFE',
#  'CALON',
#  'AOON',
#  'OPTON',
#  'AOFRAMES',
#  'M2OFFLOA',
#  'CALTIP',
#  'CALTILT',
#  'CALFOCU',
#  'RMSERR',
#  'AVGRNOT',
#  'FLUX',
#  'CALLOOP',
#  'AOCLOOP',
#  'WOFLOOP',
#  'AOTTLOOP',
#  'AOMINSNR',
#  'CALBTIP',
#  'CALBTILT',
#  'CALFOCUS',
#  'M1OFLOAD',
#  'GMPVER',
#  'GDSVER',
#  'IFSVER',
#  'AOVER',
#  'CALVER',
#  'TLCVER',
#  'NEXTEND',
#  'DATE-OBS',
#  'UTSTART',
#  'UTEND',
#  'CCDSIZE']
